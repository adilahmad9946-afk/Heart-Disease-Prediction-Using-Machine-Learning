# %% [markdown]
# ## l. Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## II. Importing and understanding our dataset

# %%
heart_data = pd.read_csv('heart.csv')

# %% [markdown]
# #### Verifying it as a 'dataframe' object in pandas

# %%
type(heart_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Shape of dataset

# %%
heart_data.shape
# Out:
# (1025, 14)

# %% [markdown]
# #### Printing first and last 5 rows of the dataset

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# #### Numbers of rows and columns in the dataset

# %%
heart_data.shape
# Out:
# (1025, 14)

# %% [markdown]
# #### Description

# %%
heart_data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# #### Checking for missing values

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
###Luckily, we have no missing values

# %% [markdown]
# #### Let's understand our columns better:

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]




for i in range(len(info)):
    print(heart_data.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# #### Analysing the 'target' variable

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
# In target column 1---> represent healty heart and 0----> represent Defective heart

# %%
heart_data['target'].describe()
# Out:
# count    1025.000000
# mean        0.513171
# std         0.500070
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %% [markdown]
# #### Checking for duplicates value

# %%
heart_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020     True
# 1021     True
# 1022     True
# 1023     True
# 1024     True
# Length: 1025, dtype: bool

# %%
heart_data.duplicated().sum()
# Out:
# np.int64(723)

# %%
#heart_data.drop_duplicates(inplace=True)

# %% [markdown]
# ## lll. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### First, analysing the target variable:

# %%
y = heart_data["target"]
target_temp = heart_data.target.value_counts()
print(target_temp)
sns.countplot(x=y,palette='pastel')
plt.title("Heart Disease Count")
plt.xlabel('Target (0=No Disease,1=Disease)')
plt.ylabel('Count')
plt.show()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
total = sum(target_temp)
print("Percentage of patience without heart problems: ",str(round(target_temp[0]*100/total,2 )))
print("Percentage of patience with heart problems: ",str(round(target_temp[1]*100/total,2 )))
# Out:
# Percentage of patience without heart problems:  48.68
# Percentage of patience with heart problems:  51.32

# %% [markdown]
# ### We'll analyse 'sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca' and 'thal' features

# %% [markdown]
# ### Analysing the 'Sex' feature

# %%
heart_data["sex"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ##### We notice, that as expected, the 'sex' feature has 2 unique features

# %%
sns.barplot(x=heart_data['sex'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Sex")
plt.xlabel("Sex (0 = Female , 1=Male)")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# ##### We notice, that females are more likely to have heart problems than males

# %% [markdown]
# ### Analysing the 'Chest Pain Type' feature

# %%
heart_data["cp"].unique()
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ##### As expected, the CP feature has values from 0 to 3

# %%
sns.barplot(x=heart_data['cp'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Chest Pain Type ")
plt.xlabel("Chest Pain Type")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# #### chest pain type, 0: typical angina, 1: atypical angina, 2: non-anginal pain, 4: asymptomatic

# %% [markdown]
# ##### We notice, that chest pain of '0', i.e. the ones with typical angina are much less likely to have heart problems

# %% [markdown]
# ### Analysing the FBS feature

# %%
heart_data["fbs"].describe()
# Out:
# count    1025.000000
# mean        0.149268
# std         0.356527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: fbs, dtype: float64

# %%
heart_data["fbs"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(x=heart_data['fbs'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Diesease Frequency by Fasting Blood Sugar")
plt.xlabel("Fasting Blood Sugar ( 0 :<= 120 mg/dl, 1: > 120 mg/dl)")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# ##### Nothing extraordinary here

# %% [markdown]
# ### Analysing the restecg feature

# %%
heart_data["restecg"].unique()
# Out:
# array([1, 0, 2])

# %%
sns.barplot(x=heart_data['restecg'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Resting ECG Results ")
plt.xlabel("Resting ECG Results")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# ##### We realize that people with restecg '1' and '0' are much more likely to have a heart disease than with restecg '2'

# %% [markdown]
# ### Analysing the 'exang' feature

# %%
heart_data["exang"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(x=heart_data['exang'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Exercise-Included Angina ")
plt.xlabel("Exercise-Included Angina")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# ##### People with exang=1 i.e. Exercise induced angina are much less likely to have heart problems

# %% [markdown]
# ### Analysing the Slope feature

# %%
heart_data["slope"].unique()
# Out:
# array([2, 0, 1])

# %%
sns.barplot(x=heart_data['slope'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Peak Exercise ST Segment")
plt.xlabel("Slope Type")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# ##### We observe, that Slope '2' causes heart pain much more than Slope '0' and '1'

# %% [markdown]
# ### Analysing the 'ca' feature

# %%
#number of major vessels (0-3) colored by flourosopy

# %%
heart_data["ca"].unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
sns.barplot(x=heart_data['ca'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Number of Major Vessels")
plt.xlabel("Number of Major Vessels Colored (ca)")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %% [markdown]
# ##### ca=4 has astonishingly large number of heart patients

# %% [markdown]
# ### Analysing the 'thal' feature

# %%
heart_data["thal"].unique()
# Out:
# array([3, 2, 1, 0])

# %%
sns.barplot(x=heart_data['thal'],y=y,data=heart_data,palette='pastel')
plt.title("Heart Disease Frequency by Thalassemia Type")
plt.xlabel("Thalassemia Type")
plt.ylabel("Probability of Heart Disease")
plt.show()

# %%
sns.distplot(heart_data["thal"])
plt.title("Disrtibution of Thalassemia Types")
plt.xlabel("The Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Analysing numerical features

# %%
num_cols = ['age','thalach','oldpeak','chol','threstbps']
for cols in num_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(heart_data[cols],kde=True)
    plt.title(f"Disrtribution of {cols}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'threstbps'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 4
#       2 for cols in num_cols:
# ...

# %% [markdown]
# ## IV. Train Test split

# %% [markdown]
# ### Importing function from libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Splitting the Features and Target

# %%
X = heart_data.drop(columns='target',axis=1)
Y = heart_data['target']

# %%
print(X)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %% [markdown]
# ### Splitting the Data into Training data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1025, 13) (820, 13) (205, 13)

# %% [markdown]
# ## V. Model Training

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression()

# %% [markdown]
# #### Training the LogisticRegression model with Training data

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Vl. Model Evaluation

# %% [markdown]
# ### Accuracy Score

# %% [markdown]
# #### Accuracy on training data

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on Training Data : ", training_data_accuracy)
# Out:
# Accuracy on Training Data :  0.8524390243902439

# %%
X_pred_lr = model.predict(X_train)

# %%
score_lr = round(accuracy_score(X_pred_lr,Y_train)*100,2)

print("The accuracy score achieved using Logistic Regression in Training Data is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression in Training Data is: 85.24 %

# %% [markdown]
# #### Accuracy on test data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy on Test Data : ", test_data_accuracy)
# Out:
# Accuracy on Test Data :  0.8048780487804879

# %%
Y_pred_lr = model.predict(X_test)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression in Test Data is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression in Test Data is: 80.49 %

# %% [markdown]
# ## Vll. Building a Predictive System

# %%
input_data=(58,0,0,100,248,0,0,122,0,1,1,0,2)

# change the input data to a numpy array

input_data_as_numpy_array=np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance

input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)

print(prediction)

if (prediction[0]==0):
    print("The Person does not have a Heart Disease")
else:
    print("The Person has Heart Disease")
# Out:
# [1]
# The Person has Heart Disease
